# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
con = sqlite3.connect('im.db')

# %%
data = pd.read_sql('SELECT * FROM final', con)

# %%
rj = data[data['primaryName'] == 'Ron Jeremy'][['primaryTitle', 'genres']]

# %%
rj['genres'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
